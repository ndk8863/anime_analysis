# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
from pathlib import Path




folder_path ='data/raw'
files = {}

for file in os.listdir(folder_path):
    # listdirでファイル名を取得し、フォルダのパスと結合することで、完全なファイルパスを作成
    if os.path.isfile(os.path.join(folder_path,file)):
        f = file.split('.')[0]
        files[f] = file
        print(f)

# data_set_name = 'anime-filtered'
# data_set_name = 'anime-dataset-2023'
data_set_name = 'final-animedataset'
# data_set_name = 'anime-dataset-2023'
# data_set_name = 'anime-dataset-2023'
# data_set_name = 'anime-dataset-2023'
# data_set_name = 'anime-dataset-2023'
df = pd.read_csv(os.path.join(folder_path,files[data_set_name]),low_memory=True)
# print(anime_df.head())
# print(anime_df.info())
# print(anime_df.describe())
# print(anime_df.columns)
# df.tail(10)


# print(df.head())
# print(df.info())
# print(df.describe()) 
# df.columns
# df.isnull().sum()
# df.duplicated().sum()

# sns.boxplot(df)

# df['Name'].unique()
# len(df['Name'].unique())
# # df.count()
# df['Name'].value_counts()[lambda x :x >=2]

df.info()
# Out:
# anime-dataset-2023
# anime-filtered
# final-animedataset
# user-filtered
# users-details-2023
# users-score-2023
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[186], line 29
#      24 data_set_name = 'final-animedataset'
#      25 # data_set_name = 'anime-dataset-2023'
#      26 # data_set_name = 'anime-dataset-2023'
#      27 # data_set_name = 'anime-dataset-2023'
#      28 # data_set_name = 'anime-dataset-2023'
# ---> 29 df = pd.read_csv(os.path.join(folder_path,files[data_set_name]),low_memory=True)
#      30 # print(anime_df.head())
#      31 # print(anime_df.info())
#      32 # print(anime_df.describe())
#    (...)
#      48 # # df.count()
#      49 # df['Name'].value_counts()[lambda x :x >=2]
#      51 df.info()
#
# ...

# %%
# data_set_name = 'anime-filtered'
# data_set_name = 'anime-dataset-2023'
data_set_name = 'final_animedataset'
# data_set_name = 'anime-dataset-2023'
# data_set_name = 'anime-dataset-2023'
# data_set_name = 'anime-dataset-2023'
# data_set_name = 'anime-dataset-2023'
df = pd.read_csv(os.path.join(folder_path,files[data_set_name]))



# df.head()
print(files)
# df.columns
# df.isnull().sum()
# df.duplicated().sum()

# sns.boxplot(df)
# Out:
# {'anime-dataset-2023': 'anime-dataset-2023.csv', 'anime-filtered': 'anime-filtered.csv', 'final_animedataset': 'final_animedataset.csv', 'user-filtered': 'user-filtered.csv', 'users-details-2023': 'users-details-2023.csv', 'users-score-2023': 'users-score-2023.csv'}

# %%
# df[df['genre'].isnull()]
# df.duplicated().sum()
df.describe()
# Out:
#            anime_id      my_score       user_id         score     scored_by  \
# count  3.530570e+07  3.530570e+07  3.530570e+07  3.530570e+07  3.530570e+07
# mean   1.148159e+04  4.591388e+00  1.863856e+06  7.527708e+00  1.096508e+05
# std    1.121719e+04  3.909503e+00  1.963096e+06  7.279344e-01  1.479300e+05
# min    1.000000e+00  0.000000e+00  1.000000e+00  1.900000e+00  2.000000e+02
# 25%    1.661000e+03  0.000000e+00  2.130750e+05  7.110000e+00  1.737600e+04
# 50%    7.724000e+03  6.000000e+00  1.057347e+06  7.560000e+00  5.388100e+04
# 75%    1.911700e+04  8.000000e+00  3.557933e+06  8.030000e+00  1.396270e+05
# max    3.786300e+04  1.000000e+01  7.251737e+06  9.250000e+00  1.009477e+06
#
#                rank    popularity
# count  3.455372e+07  3.530570e+07
# mean   2.045874e+03  1.335952e+03
# std    1.972325e+03  1.563161e+03
# min    1.000000e+00  1.000000e+00
# 25%    5.000000e+02  2.510000e+02
# 50%    1.414000e+03  7.690000e+02
# 75%    3.039000e+03  1.824000e+03
# ...

# %%
data_set_name = 'anime-filtered'
# data_set_name = 'anime-dataset-2023'
# data_set_name = 'final_animedataset'
# data_set_name = 'anime-dataset-2023'
# data_set_name = 'anime-dataset-2023'
# data_set_name = 'anime-dataset-2023'
# data_set_name = 'anime-dataset-2023'
df = pd.read_csv(os.path.join(folder_path,files[data_set_name]))

# %%
df.isnull().sum()
df[df['Ranked'].isnull()]
df[df['sypnopsis'].isnull()]
# Out:
#        anime_id                                               Name  Score  \
# 165         188                                      Gosenzo San'e   6.11
# 180         203                                        Words Worth   6.75
# 188         211                                          Pure Mail   6.26
# 190         213                             Pia Carrot e Youkoso!!   6.02
# 191         214                           Pia Carrot e Youkoso!! 2   6.15
# ...         ...                                                ...    ...
# 14801     44193                   Ano Ko no Kawari ni Suki na Dake   5.91
# 14802     44194                                 Haitoku no Kyoukai   6.18
# 14808     44211  Rikujoubu Joshi wa Ore no Nama Onaho!!! The An...   6.51
# 14866     45731                   Argonavis from BanG Dream! Movie   6.51
# 14876     46095                          Vivy: Fluorite Eye's Song   6.51
#
#                                           Genres             English name  \
# ...

# %%
data_set_name = 'user-filtered'

df = pd.read_csv(os.path.join(folder_path,files[data_set_name]))

# %%
df
# Out:
#            user_id  anime_id  rating
# 0                0        67       9
# 1                0      6702       7
# 2                0       242      10
# 3                0      4898       0
# 4                0        21      10
# ...            ...       ...     ...
# 109224742   353404       507       7
# 109224743   353404       392       9
# 109224744   353404       882       6
# 109224745   353404       883       8
# 109224746   353404       149       0
#
# [109224747 rows x 3 columns]

# %%
data_set_name = 'users-details-2023'

df = pd.read_csv(os.path.join(folder_path,files[data_set_name]))
df
# Out:
#          Mal ID    Username  Gender                   Birthday  \
# 0             1       Xinil    Male  1985-03-04T00:00:00+00:00
# 1             3     Aokaado    Male                        NaN
# 2             4     Crystal  Female                        NaN
# 3             9      Arcane     NaN                        NaN
# 4            18         Mad     NaN                        NaN
# ...         ...         ...     ...                        ...
# 731285  1291083      Dolopa     NaN                        NaN
# 731286  1291085  alenrobnik     NaN                        NaN
# 731287  1291087   Oblongata     NaN  1993-01-30T00:00:00+00:00
# 731288  1291091      Etnota     NaN                        NaN
# 731289  1291097  JuunanaSai  Female                        NaN
#
#                     Location                     Joined  Days Watched  \
# 0                 California  2004-11-05T00:00:00+00:00         142.3
# ...

# %%
# df.info()
df['Birthday'].value_counts()
# df['Birthday'].isnull().sum()
# Out:
# Birthday
# 1990-01-01T00:00:00+00:00    177
# 1989-03-26T00:00:00+00:00    169
# 1980-01-01T00:00:00+00:00    166
# 1930-01-01T00:00:00+00:00    153
# 1991-01-01T00:00:00+00:00    115
#                             ...
# 1966-12-06T00:00:00+00:00      1
# 2001-11-08T00:00:00+00:00      1
# 1954-10-16T00:00:00+00:00      1
# 1958-03-13T00:00:00+00:00      1
# 2000-10-13T00:00:00+00:00      1
# Name: count, Length: 11247, dtype: int64

# %%
731282 - 563222
# Out:
# 168060

# %%
df.duplicated().sum()
# Out:
# 0

# %%
data_set_name = 'users-score-2023'

df = pd.read_csv(os.path.join(folder_path,files[data_set_name]))
df['Username'].value_counts()
# Out:
# Username
# trafagibr        2986
# Furrek           2890
# ArcherEmiya24    2885
# Sitha            2868
# mardi            2863
#                  ...
# Akasuka             1
# 7assony             1
# khain667            1
# Newauroradark       1
# jade22              1
# Name: count, Length: 270032, dtype: int64

# %%
# Out:
# ----------------------------------------------------------------
# TypeError                      Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
from pathlib import Path




folder_path ='data/raw'
files = {}

for file in os.listdir(folder_path):
    # listdirでファイル名を取得し、フォルダのパスと結合することで、完全なファイルパスを作成
    if os.path.isfile(os.path.join(folder_path,file)):
        f = file.split('.')[0]
        files[f] = file
        print(f)


data_set_name = 'anime-filtered'
df = pd.read_csv(os.path.join(folder_path,files[data_set_name]))

df.columns
df.isnull().sum()
df.duplicated().sum()
# Out:
# anime-dataset-2023
# anime-filtered
# final-animedataset
# user-filtered
# users-details-2023
# users-score-2023
# 0

# %%
# df.columns

# for col in df.columns:
#     print(col)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14952 entries, 0 to 14951
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anime_id       14952 non-null  int64
#  1   Name           14952 non-null  object
#  2   Score          14952 non-null  float64
#  3   Genres         14952 non-null  object
#  4   English name   14952 non-null  object
#  5   Japanese name  14952 non-null  object
#  6   sypnopsis      13602 non-null  object
#  7   Type           14952 non-null  object
#  8   Episodes       14952 non-null  object
#  9   Aired          14952 non-null  object
#  10  Premiered      14952 non-null  object
#  11  Producers      14952 non-null  object
#  12  Licensors      14952 non-null  object
#  13  Studios        14952 non-null  object
#  14  Source         14952 non-null  object
#  15  Duration       14952 non-null  object
#  16  Rating         14952 non-null  object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anime_id      24905 non-null  int64
#  1   Name          24905 non-null  object
#  2   English name  24905 non-null  object
#  3   Other name    24905 non-null  object
#  4   Score         24905 non-null  object
#  5   Genres        24905 non-null  object
#  6   Synopsis      24905 non-null  object
#  7   Type          24905 non-null  object
#  8   Episodes      24905 non-null  object
#  9   Aired         24905 non-null  object
#  10  Premiered     24905 non-null  object
#  11  Status        24905 non-null  object
#  12  Producers     24905 non-null  object
#  13  Licensors     24905 non-null  object
#  14  Studios       24905 non-null  object
#  15  Source        24905 non-null  object
#  16  Duration      24905 non-null  object
#  17  Rating        24905 non-null  object
# ...

# %%
data_set_name = 'users-score-2023'
df = pd.read_csv(os.path.join(folder_path,files[data_set_name]))

df.columns

for col in df.columns:
    print(col)
# Out:
# user_id
# Username
# anime_id
# Anime Title
# rating

# %%
# ユーザーデータ探索


data_set_name = 'user-filtered'
filterd_df = pd.read_csv(os.path.join(folder_path,files[data_set_name]))


data_set_name = 'users-details-2023'
details_df = pd.read_csv(os.path.join(folder_path,files[data_set_name]))


data_set_name = 'users-score-2023'
score_df = pd.read_csv(os.path.join(folder_path,files[data_set_name]))

# %%
filterd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109224747 entries, 0 to 109224746
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 2.4 GB

# %%
score_df['anime_id'].value_counts()
# Out:
# anime_id
# 1535     126492
# 1575      96950
# 121       93001
# 269       90132
# 20        89579
#           ...
# 37678         1
# 10997         1
# 10882         1
# 24663         1
# 47231         1
# Name: count, Length: 16500, dtype: int64

# %%
filterd_df['anime_id'].value_counts()
filterd_df.head(100)
# Out:
#     user_id  anime_id  rating
# 0         0        67       9
# 1         0      6702       7
# 2         0       242      10
# 3         0      4898       0
# 4         0        21      10
# ..      ...       ...     ...
# 95        1      3972       7
# 96        1       481       8
# 97        1     22199       7
# 98        1      6547       6
# 99        1      9919       8
#
# [100 rows x 3 columns]

# %%
details_df.head(100)
# Out:
#     Mal ID Username  Gender                   Birthday              Location  \
# 0        1    Xinil    Male  1985-03-04T00:00:00+00:00            California
# 1        3  Aokaado    Male                        NaN          Oslo, Norway
# 2        4  Crystal  Female                        NaN  Melbourne, Australia
# 3        9   Arcane     NaN                        NaN                   NaN
# 4       18      Mad     NaN                        NaN                   NaN
# ..     ...      ...     ...                        ...                   ...
# 95     384      Rie  Female                        NaN               WA, USA
# 96     390  martino    Male                        NaN                Europe
# 97     392   Touhou    Male                        NaN                 Japan
# 98     396  Sources     NaN                        NaN                   NaN
# 99     399    roarg     NaN                        NaN                   NaN
#
# ...

# %%
score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24325191 entries, 0 to 24325190
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   user_id      int64
#  1   Username     object
#  2   anime_id     int64
#  3   Anime Title  object
#  4   rating       int64
# dtypes: int64(3), object(2)
# memory usage: 927.9+ MB

# %%
score_join_user_detials_df = pd.merge(details_df,score_df,left_on = 'Mal ID',right_on ='user_id',how = 'left')
score_join_user_detials_df.head()
# Out:
#    Mal ID Username_x Gender                   Birthday    Location  \
# 0       1      Xinil   Male  1985-03-04T00:00:00+00:00  California
# 1       1      Xinil   Male  1985-03-04T00:00:00+00:00  California
# 2       1      Xinil   Male  1985-03-04T00:00:00+00:00  California
# 3       1      Xinil   Male  1985-03-04T00:00:00+00:00  California
# 4       1      Xinil   Male  1985-03-04T00:00:00+00:00  California
#
#                       Joined  Days Watched  Mean Score  Watching  Completed  \
# 0  2004-11-05T00:00:00+00:00         142.3        7.37       1.0      233.0
# 1  2004-11-05T00:00:00+00:00         142.3        7.37       1.0      233.0
# 2  2004-11-05T00:00:00+00:00         142.3        7.37       1.0      233.0
# 3  2004-11-05T00:00:00+00:00         142.3        7.37       1.0      233.0
# 4  2004-11-05T00:00:00+00:00         142.3        7.37       1.0      233.0
#
#    ...  Dropped  Plan to Watch  Total Entries  Rewatched  Episodes Watched  \
# ...

# %%
details_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731290 entries, 0 to 731289
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Mal ID            731290 non-null  int64
#  1   Username          731289 non-null  object
#  2   Gender            224383 non-null  object
#  3   Birthday          168068 non-null  object
#  4   Location          152805 non-null  object
#  5   Joined            731290 non-null  object
#  6   Days Watched      731282 non-null  float64
#  7   Mean Score        731282 non-null  float64
#  8   Watching          731282 non-null  float64
#  9   Completed         731282 non-null  float64
#  10  On Hold           731282 non-null  float64
#  11  Dropped           731282 non-null  float64
#  12  Plan to Watch     731282 non-null  float64
#  13  Total Entries     731282 non-null  float64
#  14  Rewatched         731282 non-null  float64
# ...
